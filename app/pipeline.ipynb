# %%
# necessary imports
import numpy as np
import pandas as pd
import plotly.express as px

from sklearn.preprocessing import PolynomialFeatures
from fetcher import fetch_maps, fetch_scores

# %% [markdown]
# ### Fetch Maps and Scores

# %%
# get ranked maps
maps_df = fetch_maps()

# %%
maps_df.head()
# Out:
#   leaderboardId  songId                                              cover  \
# 0         57c31     57c  https://eu.cdn.beatsaver.com/f15082586d31d238c...
# 1         57c51     57c  https://eu.cdn.beatsaver.com/f15082586d31d238c...
# 2         57c71     57c  https://eu.cdn.beatsaver.com/f15082586d31d238c...
# 3      1fd41x11  1fd41x  https://eu.cdn.beatsaver.com/1fb8d26ef00049d75...
# 4      1fd41x31  1fd41x  https://eu.cdn.beatsaver.com/1fb8d26ef00049d75...
#
#                                            fullCover       name  \
# 0  https://cdn.assets.beatleader.xyz/songcover-57...        Zzz
# 1  https://cdn.assets.beatleader.xyz/songcover-57...        Zzz
# 2  https://cdn.assets.beatleader.xyz/songcover-57...        Zzz
# 3  https://cdn.assets.beatleader.xyz/songcover-1f...  Zombified
# 4  https://cdn.assets.beatleader.xyz/songcover-1f...  Zombified
#
#             subName              author    mapper    bpm  duration     stars  \
# 0  by Sasaki Sayaka            Todokete  todokete  154.0       248  3.565262
# 1  by Sasaki Sayaka            Todokete  todokete  154.0       248  5.456755
# 2  by Sasaki Sayaka            Todokete  todokete  154.0       248  6.634682
# 3                    Falling In Reverse   Bytrius  182.0       221  2.996581
# 4                    Falling In Reverse   Bytrius  182.0       221  4.168840
#
#    passRating  accRating  techRating difficultyName      type  mod_stars  \
# 0    0.992113   5.772469    3.247698         Normal  Accuracy   3.565262
# 1    2.433202   7.259916    6.221073           Hard      Tech   5.456755
# 2    3.184074   8.040394    8.696276         Expert      Tech   6.634682
# 3    1.331649   5.175914    1.158910           Easy  Accuracy   2.996581
# 4    2.345820   6.326489    1.984545         Normal  Accuracy   4.168840
#
#    mod_passRating  mod_accRating  mod_techRating
# 0        0.992113       5.772469        3.247698
# 1        2.433202       7.259916        6.221073
# 2        3.184074       8.040394        8.696276
# 3        1.331649       5.175914        1.158910
# 4        2.345820       6.326489        1.984545

# %%
# get player scores
id = "thinkingswag"
scores_df = fetch_scores(id)

# %%
scores_df.head()
# Out:
#      leaderboardId         songId  \
# 0        2b85fxx71        2b85fxx
# 1  3bcf5xxxxxxxx91  3bcf5xxxxxxxx
# 2          1cd7791          1cd77
# 3          2a1b391          2a1b3
# 4          1cdc691          1cdc6
#
#                                                cover  \
# 0  https://eu.cdn.beatsaver.com/09fd6d30c55f6d721...
# 1  https://cdn.beatsaver.com/187bea15de6bd7301239...
# 2  https://eu.cdn.beatsaver.com/08d67c25e377d2013...
# 3  https://eu.cdn.beatsaver.com/604ac21a79c26207c...
# 4  https://eu.cdn.beatsaver.com/eaddeb51358bbd688...
#
#                                            fullCover  \
# 0  https://cdn.assets.beatleader.xyz/songcover-2b...
# 1  https://cdn.assets.beatleader.xyz/songcover-3b...
# 2  https://cdn.assets.beatleader.xyz/songcover-1c...
# 3  https://cdn.assets.beatleader.xyz/songcover-2a...
# 4  https://cdn.assets.beatleader.xyz/songcover-1c...
#
#                                                 name            subName  \
# 0  At Least Speedcore Artists Aren't In It For Th...
# 1                                        nieuwe tune
# 2                                          Deception
# 3                      II. Anal Prolapse Suffocation
# 4                   We Like To Party! (The Vengabus)  [Fvrwvrd Bootleg]
#
#                            author         mapper    bpm  duration  ...  \
# 0             Loffciamcore & Imil          Slayx  260.0       143  ...
# 1  gladde paling & vieze vaatdoek  Stupidity-101  180.0        93  ...
# 2               Dance Gavin Dance         cerret  316.0       233  ...
# 3              Infant Annihilator        Vilawes  350.0       182  ...
# 4                       Vengaboys         cerret  320.0       125  ...
#
#    mod_passRating  mod_accRating  mod_techRating  mod_stars  accuracy  \
# 0       15.041139      11.934061        2.134165   7.976207  0.974111
# 1       17.206710      13.184697       11.334187  14.775179  0.941264
# 2       15.924928      11.720812        2.477255   8.379396  0.969104
# 3       14.132151      11.225502        1.858116  10.196410  0.974313
# 4       13.822477      11.683339        2.319518  10.649382  0.972415
#
#           pp  rank  modifiers  fullCombo             dateset
# 0  840.22034     2         SF       True 2023-01-25 17:58:22
# 1  794.43090     2         FS      False 2024-12-13 18:49:16
# 2  783.93976     2         SF      False 2023-05-13 14:04:36
# 3  773.77510     2         FS       True 2023-03-15 18:38:45
# 4  768.43270     3         FS       True 2023-03-15 18:27:35
#
# [5 rows x 26 columns]

# %%
# calculate days since scores were set
max_date = scores_df["dateset"].max()
scores_df["days_since"] = (max_date - scores_df["dateset"]).dt.days

# %% [markdown]
# ### Train Model

# %% [markdown]
# Decay Function: $\text{Weight}(t) = e^{-\lambda \times \frac{\text{days since}}{14}}$

# %%
# apply weighted decay function so newer scores have more influence on the model
lambda_value = 0.1
decay_weights = np.exp(-lambda_value * scores_df["days_since"] / 14) # 2 weeks
scores_df["decay_weights"] = decay_weights

# %%
# set up features for exponential regression model

# modified ratings as independent variables
X = scores_df[["mod_passRating", "mod_accRating", "mod_techRating"]].values.reshape(-1, 3)
X_poly = PolynomialFeatures(degree=2, include_bias=False).fit_transform(X)

# dependent variable; invert to mimic downward curve
y = scores_df["accuracy"].to_numpy().reshape(-1, 1)
y_inv = (1 - scores_df["accuracy"]).to_numpy().reshape(-1, 1)
y_inv_log = np.log(y_inv)

# %% [markdown]
# LOBF Equation: $\text{model} = (X^TWX)^{-1}X^TWy$

# %%
# train model
W = np.diag(decay_weights)
X_poly_bias = np.column_stack([np.ones(X_poly.shape[0]), X_poly])

XtW = np.matmul(X_poly_bias.T, W)
XtWX_inv = np.linalg.inv(np.matmul(XtW, X_poly_bias))
XtWy = np.matmul(XtW, y_inv_log)

model = np.matmul(XtWX_inv, XtWy)
model
# Out:
# array([[-5.88277658e+00],
#        [-7.42769537e-02],
#        [ 3.44152759e-01],
#        [-3.78696420e-02],
#        [ 9.43020322e-03],
#        [-1.37723573e-02],
#        [-5.70035940e-04],
#        [ 2.26044003e-06],
#        [-2.88758128e-03],
#        [ 8.53622321e-03]])

# %% [markdown]
# ### Predict Scores

# %%
# predict scores
ypreds_inv = np.dot(X_poly, model[1:]) + model[0]
ypreds = 1 - np.exp(ypreds_inv)

scores_df["pred_accuracy"] = ypreds
scores_df[["accuracy", "pred_accuracy"]].head()
# Out:
#    accuracy  pred_accuracy
# 0  0.974111       0.965439
# 1  0.941264       0.941027
# 2  0.969104       0.965211
# 3  0.974313       0.969391
# 4  0.972415       0.968227

# %%
from models import PRED_FEATURES
from pp import WEIGHT_CURVE, calc_pp_from_accuracy
from utils import filter_unplayed

PRED_FEATURES = ['leaderboardId', 'songId', 'cover', 'fullCover', 'name', 'subName',
                 'author', 'mapper', 'bpm', 'duration', 'difficultyName', 'type',
                 'stars', 'passRating', 'accRating', 'techRating', 
                 'mod_stars','mod_passRating', 'mod_accRating', 'mod_techRating', 
                 "status", "modifiers", "current_acc", "pred_acc", "acc_gain",
                 "current_pp", "pred_pp", "max_pp",
                 "unweighted_pp_gain", "weighted_pp_gain", "weights"]

def apply_weight_curve(pred_df: pd.DataFrame) -> pd.DataFrame:
  weighted_df = pred_df.copy()
  
  weighted_df = weighted_df.sort_values(by="max_pp", ascending=False)
  current_pp = weighted_df["current_pp"].sort_values(ascending=False).to_numpy()

  weights = np.zeros(len(pred_df))
  weight_idx = 0
  curve_idx = 0

  for _, row in weighted_df.iterrows():
    if curve_idx < len(WEIGHT_CURVE) - 1 and row["max_pp"] < current_pp[curve_idx]:
      curve_idx += 1
    weights[weight_idx] = WEIGHT_CURVE[curve_idx]
    weight_idx += 1
  
  weighted_df["weighted_pp_gain"] = weighted_df["unweighted_pp_gain"] * weights
  weighted_df["weights"] = weights

  return weighted_df

unplayed_df = filter_unplayed(scores_df, maps_df)
scores_df["status"] = "played"; unplayed_df["status"] = "unplayed"
pred_df = pd.concat([scores_df, unplayed_df], ignore_index=True)

X = pred_df[["mod_passRating", "mod_accRating", "mod_techRating"]].values.reshape(-1, 3)
X_poly = PolynomialFeatures(degree=2, include_bias=False).fit_transform(X)

pred_df["current_acc"] = np.where(~pred_df["accuracy"].isna(), pred_df["accuracy"], 0)
pred_df["pred_acc"] = np.minimum(1, 1 - np.exp(np.dot(X_poly, model[1:]) + model[0]))
pred_df["acc_gain"] = np.maximum(0, pred_df["pred_acc"] - pred_df["current_acc"])

pred_df["current_pp"] = np.where(~pred_df["pp"].isna(), pred_df["pp"], 0)
pred_df["pred_pp"] = pred_df.apply(lambda row: calc_pp_from_accuracy(
  row["pred_acc"], row["mod_passRating"], row["mod_accRating"], row["mod_techRating"])["total_pp"], 
  axis=1)
pred_df["max_pp"] = np.maximum(pred_df["current_pp"], pred_df["pred_pp"])
pred_df["unweighted_pp_gain"] = np.maximum(0, pred_df["pred_pp"] - pred_df["current_pp"])
pred_df = apply_weight_curve(pred_df)

pred_df = pred_df[PRED_FEATURES].sort_values(by="max_pp", ascending=False)

# %%
pred_df.head(30)
# Out:
#            leaderboardId            songId  \
# 0              2b85fxx71           2b85fxx
# 805   3ce7axxxxxxxxxxx91  3ce7axxxxxxxxxxx
# 35               1ac1791             1ac17
# 20               1ace571             1ace5
# 1        3bcf5xxxxxxxx91     3bcf5xxxxxxxx
# 231              1a59391             1a593
# 2                1cd7791             1cd77
# 7                2b57191             2b571
# 1017        2c888xxxxx91        2c888xxxxx
# 182              13b2b71             13b2b
# 2604       3c010xxxxxx91       3c010xxxxxx
# 49               1df6891             1df68
# 3                2a1b391             2a1b3
# 80               290c991             290c9
# 220              1a55e91             1a55e
# 1810      31d13xxxxxxx91      31d13xxxxxxx
# 104              1a52391             1a523
# 4                1cdc691             1cdc6
# 964           38606xxx91          38606xxx
# 426             24d9bx91            24d9bx
# 148              1a80e91             1a80e
# 130              1a55291             1a552
# 85                e72b91              e72b
# 1016       2dd30xxxxxx91       2dd30xxxxxx
# 987            2c220xx91           2c220xx
# 5                277b791             277b7
# 33               2cc5d91             2cc5d
# 6                1451391             14513
# 2408           345b9xx91           345b9xx
# 2518           338afxx91           338afxx
#
#                                                   cover  \
# 0     https://eu.cdn.beatsaver.com/09fd6d30c55f6d721...
# 805   https://cdn.beatsaver.com/6343bbda0b1c75d52423...
# 35    https://eu.cdn.beatsaver.com/8cf4844d5dd772821...
# 20    https://eu.cdn.beatsaver.com/61caada06a65088bd...
# 1     https://cdn.beatsaver.com/187bea15de6bd7301239...
# 231   https://eu.cdn.beatsaver.com/471b5a6822576df5d...
# 2     https://eu.cdn.beatsaver.com/08d67c25e377d2013...
# 7     https://eu.cdn.beatsaver.com/429ff959e81100e5a...
# 1017  https://eu.cdn.beatsaver.com/3f567bc5cc7ada8c9...
# 182   https://eu.cdn.beatsaver.com/2e887f6cd0fa896a8...
# 2604  https://cdn.beatsaver.com/aac532e2004f0c0e99b3...
# 49    https://eu.cdn.beatsaver.com/3df1614a21f1927ad...
# 3     https://eu.cdn.beatsaver.com/604ac21a79c26207c...
# 80    https://eu.cdn.beatsaver.com/d99db4c1d15d7ed66...
# 220   https://eu.cdn.beatsaver.com/7091e07305aab0e1e...
# 1810  https://cdn.beatsaver.com/881bdd4f5e7c05021f7c...
# 104   https://eu.cdn.beatsaver.com/8dea324524baf1ed5...
# 4     https://eu.cdn.beatsaver.com/eaddeb51358bbd688...
# 964   https://na.cdn.beatsaver.com/caefc569fbc0bf03f...
# 426   https://eu.cdn.beatsaver.com/6e9498f81bbf26fa4...
# 148   https://eu.cdn.beatsaver.com/0bf56fa581064964f...
# 130   https://eu.cdn.beatsaver.com/666eeac0f3eee2278...
# 85    https://eu.cdn.beatsaver.com/5eea46e7779609139...
# 1016  https://na.cdn.beatsaver.com/8f2df8a22bcf7f7cd...
# 987   https://eu.cdn.beatsaver.com/2bdc7c19dc3fe84e3...
# 5     https://eu.cdn.beatsaver.com/d7d24c7af3085d8e2...
# 33    https://eu.cdn.beatsaver.com/444548e1720dcc465...
# 6     https://eu.cdn.beatsaver.com/9ac0355075fbbcca2...
# 2408  https://na.cdn.beatsaver.com/76a2f7b11cb2734c3...
# 2518  https://na.cdn.beatsaver.com/c678f67c54e8258ac...
#
#                                               fullCover  \
# 0     https://cdn.assets.beatleader.xyz/songcover-2b...
# 805   https://cdn.assets.beatleader.xyz/songcover-3c...
# 35    https://cdn.assets.beatleader.xyz/songcover-1a...
# 20    https://cdn.assets.beatleader.xyz/songcover-1a...
# 1     https://cdn.assets.beatleader.xyz/songcover-3b...
# 231   https://cdn.assets.beatleader.xyz/songcover-1a...
# 2     https://cdn.assets.beatleader.xyz/songcover-1c...
# 7     https://cdn.assets.beatleader.xyz/songcover-2b...
# 1017  https://cdn.assets.beatleader.xyz/songcover-2c...
# 182   https://cdn.assets.beatleader.xyz/songcover-13...
# 2604  https://cdn.assets.beatleader.xyz/songcover-3c...
# 49    https://cdn.assets.beatleader.xyz/songcover-1d...
# 3     https://cdn.assets.beatleader.xyz/songcover-2a...
# 80    https://cdn.assets.beatleader.xyz/songcover-29...
# 220   https://cdn.assets.beatleader.xyz/songcover-1a...
# 1810  https://cdn.assets.beatleader.xyz/songcover-31...
# 104   https://cdn.assets.beatleader.xyz/songcover-1a...
# 4     https://cdn.assets.beatleader.xyz/songcover-1c...
# 964   https://cdn.assets.beatleader.xyz/songcover-38...
# 426   https://cdn.assets.beatleader.xyz/songcover-24...
# 148   https://cdn.assets.beatleader.xyz/songcover-1a...
# 130   https://cdn.assets.beatleader.xyz/songcover-1a...
# 85    https://cdn.assets.beatleader.xyz/songcover-e7...
# 1016  https://cdn.assets.beatleader.xyz/songcover-2d...
# 987   https://cdn.assets.beatleader.xyz/songcover-2c...
# 5     https://cdn.assets.beatleader.xyz/songcover-27...
# 33    https://cdn.assets.beatleader.xyz/songcover-2c...
# 6     https://cdn.assets.beatleader.xyz/songcover-14...
# 2408  https://cdn.assets.beatleader.xyz/songcover-34...
# 2518  https://cdn.assets.beatleader.xyz/songcover-33...
#
#                                                    name  \
# 0     At Least Speedcore Artists Aren't In It For Th...
# 805                                The Purple Dimension
# 35                                              Carmina
# 20                                     Venomous Firefly
# 1                                           nieuwe tune
# 231                                            Barbecue
# 2                                             Deception
# 7                                           Black Rover
# 1017                                     Splatter Party
# 182   Extra Credit on the Chromosome Test! VICTORY R...
# 2604                               Evacuate The Moshpit
# 49                                               Astrid
# 3                         II. Anal Prolapse Suffocation
# 80          Superluminal Absolutely EXTRA-TONE-ordinary
# 220   My Album Is Out On Dance Corps So Now I Am All...
# 1810                                          Luminency
# 104                                 POWA OF DA WILDANES
# 4                      We Like To Party! (The Vengabus)
# 964                                      SUPER EMULATOR
# 426                                           Yggdrasil
# 148                                    The X Is On Fire
# 130                            Yotsuya-san ni Yoroshiku
# 85                                             Memecore
# 1016                                    Splitting Noise
# 987                          Start of the Determination
# 5                                              een auto
# 33                                 Signal (7_7 bootleg)
# 6                                  Dyscontrolled Galaxy
# 2408                                       GALAXY BURST
# 2518                                              Feral
#
#                                                 subName  \
# 0
# 805                                    Extended Version
# 35                              (fallen shepherd Remix)
# 20
# 1
# 231
# 2
# 7
# 1017  (Feat. Hatsune Miku) [Xena Galia Cover || XH /...
# 182                                (feat. Lil Triangle)
# 2604
# 49                (nolanLMOA's "Balls n' Bass" Bootleg)
# 3
# 80    "Bumpy Ride" (Shredding Whole Your Belonging S...
# 220
# 1810
# 104
# 4                                     [Fvrwvrd Bootleg]
# 964                                    [feat. HiTNEX-X]
# 426
# 148
# 130                                     Himeringo cover
# 85
# 1016
# 987
# 5
# 33
# 6                                 (Apoptosis Long ver.)
# 2408
# 2518
#
#                               author                   mapper     bpm  \
# 0                Loffciamcore & Imil                    Slayx  260.00
# 805                       ToonTubers      Cratornugget & ViSi  464.00
# 35               CANVAS feat. Quimar                  abcbadq  195.00
# 20                          Camellia         ComplexFrequency  264.00
# 1     gladde paling & vieze vaatdoek            Stupidity-101  180.00
# 231            Igorrr & Ruby My Dear          Schwank & Jabob  200.00
# 2                  Dance Gavin Dance                   cerret  316.00
# 7                        Vickeblanka                 Aquaflee  204.04
# 1017                        Camellia    Anammelech & Otricity  216.00
# 182                          Schwank    lobster & FatBeanzoop  175.00
# 2604                            Imil                   Emilia  200.00
# 49                            glaive        Spledgey & Emilia  190.00
# 3                 Infant Annihilator                  Vilawes  350.00
# 80                          Camellia                   cerret  400.00
# 220                             Imil                   Emilia  250.00
# 1810                         Ludicin                     Fnyt  350.00
# 104                         Camellia      Atomosophere & Rune  300.00
# 4                          Vengaboys                   cerret  320.00
# 964                          Kobaryo             1100ping_boi  208.00
# 426                  Gram VS Kobaryo             GalaxyMaster  200.00
# 148                   Algorithm Dude                   Cobayo  340.00
# 130                            Eight            CoolingCloset  220.00
# 85                      HiTECH NINJA              FatBeanzoop  175.00
# 1016                   Noise Spammer                      Kip  210.00
# 987                          Kobaryo              dentalstonk  400.00
# 5                      gladde paling               WalkingKat  179.99
# 33              Rejection feat. such                    Hener  200.00
# 6                           Camellia                   Soba`s  161.00
# 2408                        Camellia                    RetrX  402.00
# 2518                        meganeko  miitchel, Jabob & Hades  160.00
#
#       duration  ... modifiers current_acc  pred_acc  acc_gain  current_pp  \
# 0          143  ...        SF    0.974111  0.965439  0.000000   840.22034
# 805        187  ...       NaN    0.000000  0.960212  0.960212     0.00000
# 35         252  ...        SF    0.947865  0.959657  0.011793   730.96545
# 20         122  ...        SF    0.952253  0.960758  0.008506   742.47500
# 1           93  ...        FS    0.941264  0.941027  0.000000   794.43090
# 231        226  ...        SF    0.923051  0.957831  0.034779   644.04830
# 2          233  ...        SF    0.969104  0.965211  0.000000   783.93976
# 7           90  ...        SF    0.964075  0.967071  0.002996   755.11520
# 1017       278  ...       NaN    0.000000  0.965528  0.965528     0.00000
# 182        132  ...        FS    0.949994  0.966460  0.016466   673.57500
# 2604       164  ...       NaN    0.000000  0.967885  0.967885     0.00000
# 49         124  ...        SF    0.957612  0.964513  0.006901   723.46500
# 3          182  ...        FS    0.974313  0.969391  0.000000   773.77510
# 80         282  ...              0.952400  0.961555  0.009155   711.81866
# 220        116  ...        SF    0.953685  0.969820  0.016136   655.23126
# 1810       265  ...       NaN    0.000000  0.965763  0.965763     0.00000
# 104        339  ...        FS    0.950289  0.961022  0.010734   703.26416
# 4          125  ...        FS    0.972415  0.968227  0.000000   768.43270
# 964        178  ...       NaN    0.000000  0.968799  0.968799     0.00000
# 426        423  ...       NaN    0.000000  0.966226  0.966226     0.00000
# 148        139  ...        FS    0.951887  0.964461  0.012574   685.17004
# 130        173  ...        SF    0.947169  0.960325  0.013156   692.93780
# 85         202  ...        FS    0.960838  0.967177  0.006339   711.06310
# 1016       203  ...       NaN    0.000000  0.966800  0.966800     0.00000
# 987        176  ...       NaN    0.000000  0.970493  0.970493     0.00000
# 5          108  ...        FS    0.973367  0.972795  0.000000   761.52210
# 33         276  ...              0.963940  0.966988  0.003049   732.29800
# 6          298  ...              0.976678  0.971717  0.000000   760.70130
# 2408       253  ...       NaN    0.000000  0.969086  0.969086     0.00000
# 2518       269  ...       NaN    0.000000  0.962129  0.962129     0.00000
#
#          pred_pp      max_pp  unweighted_pp_gain  weighted_pp_gain  weights
# 0     735.249972  840.220340            0.000000          0.000000    1.000
# 805   813.351811  813.351811          813.351811        784.884498    0.965
# 35    798.001523  798.001523           67.036073         64.689811    0.965
# 20    795.502003  795.502003           53.027003         51.171058    0.965
# 1     793.387391  794.430900            0.000000          0.000000    0.965
# 231   788.760273  788.760273          144.711973        134.726847    0.931
# 2     746.496925  783.939760            0.000000          0.000000    0.931
# 7     783.209564  783.209564           28.094364         25.256833    0.899
# 1017  778.388955  778.388955          778.388955        699.771670    0.899
# 182   776.853089  776.853089          103.278089         92.847002    0.899
# 2604  776.472843  776.472843          776.472843        698.049086    0.899
# 49    774.896187  774.896187           51.431187         46.236637    0.899
# 3     709.337162  773.775100            0.000000          0.000000    0.899
# 80    770.021848  770.021848           58.203188         50.462164    0.867
# 220   770.015451  770.015451          114.784191         99.517893    0.867
# 1810  769.788674  769.788674          769.788674        667.406780    0.867
# 104   769.391810  769.391810           66.127650         57.332673    0.867
# 4     721.075667  768.432700            0.000000          0.000000    0.867
# 964   768.254690  768.254690          768.254690        643.029175    0.837
# 426   768.135565  768.135565          768.135565        642.929468    0.837
# 148   766.302625  766.302625           81.132585         67.907974    0.837
# 130   765.890761  765.890761           72.952961         61.061628    0.837
# 85    765.675286  765.675286           54.612186         45.710399    0.837
# 1016  762.776582  762.776582          762.776582        638.443999    0.837
# 987   762.297569  762.297569          762.297569        638.043066    0.837
# 5     752.863213  761.522100            0.000000          0.000000    0.837
# 33    761.019888  761.019888           28.721888         23.207285    0.808
# 6     678.807346  760.701300            0.000000          0.000000    0.808
# 2408  759.160047  759.160047          759.160047        591.385676    0.779
# 2518  758.456953  758.456953          758.456953        590.837966    0.779
#
# [30 rows x 31 columns]

# %%
px.scatter(scores_df, x="stars", y="accuracy", color="decay_weights", color_continuous_scale="magenta",
           hover_data=["name", "mapper", "type", "difficultyName", "days_since", 
                       "mod_passRating", "mod_accRating", "mod_techRating"], 
           title="Decay Weights for Scores")

# %%
scores_df['accuracy_type'] = 'Actual'

predicted_df = scores_df[['stars', 'pred_accuracy']].copy()
predicted_df['accuracy_type'] = 'Predicted'
predicted_df = predicted_df.rename(columns={'pred_accuracy': 'accuracy'})

combined_df = pd.concat([scores_df[['stars', 'accuracy', 'accuracy_type']], predicted_df[['stars', 'accuracy', 'accuracy_type']]], ignore_index=True)

px.scatter(combined_df, x="stars", y="accuracy", color="accuracy_type", title="Actual vs. Predicted Accuracy")
